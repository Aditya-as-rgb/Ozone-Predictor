# %% [markdown]
# ## Ozone Predictor: Deep Learning Ozone Hole Prediction

# %% [markdown]
# # Imporing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing the Datasets

# %%
antarctic_ozone = pd.read_csv('antarctic-ozone-hole-area.csv')
nasa1 = pd.read_csv('NasaOzoneWatch_1.csv')
nasa2 = pd.read_csv('NasaOzoneWatch_2.csv')
odgi1 = pd.read_csv('odgi_table1.csv')
odgi2 = pd.read_csv('odgi_table2.csv')

# %%
# Keep only valid years (numeric values)
odgi1 = odgi1[pd.to_numeric(odgi1['Year'], errors='coerce').notnull()]
odgi2 = odgi2[pd.to_numeric(odgi2['Year'], errors='coerce').notnull()]

# Convert Year columns to int
odgi1['Year'] = odgi1['Year'].astype(int)
odgi2['Year'] = odgi2['Year'].astype(int)

# %%
odgi1.head()
# Out:
#    Year  CFC-12  CFC-11  CH3Cl  CH3Br   CCl4  CH3CCl3  halons  CFC-113  HCFCs  \
# 0  1992   861.0   789.0  500.0  583.0  431.0    400.0   346.0    215.0   41.0
# 1  1993   876.0   795.0  500.0  583.0  429.0    393.0   368.0    219.0   44.0
# 2  1994   885.0   796.0  501.0  583.0  425.0    370.0   394.0    224.0   48.0
# 3  1995   895.0   793.0  508.0  583.0  422.0    333.0   416.0    226.0   53.0
# 4  1996   907.0   789.0  500.0  585.0  418.0    296.0   427.0    227.0   59.0
#
#    WMO Minor  SUM* (ppt)  EESC SUM (ppt)  ODGI(old) Antarctic  \
# 0       18.0      4184.0          3544.0                 97.7
# 1       18.0      4226.0          3666.0                 99.0
# 2       18.0      4244.0          3784.0                100.0
# 3       19.0      4248.0          3888.0                 99.4
# 4       19.0      4227.0          3974.0                 99.2
#
#    ODGI(new) Antarctic
# 0                 69.6
# 1                 75.7
# 2                 81.6
# 3                 86.8
# 4                 91.1

# %%
odgi2.head()
# Out:
#    Year  CFC-12  CFC-11  CH3Cl  CH3Br   CCl4  CH3CCl3  halons  CFC-113  HCFCs  \
# 0  1992   230.0   375.0  242.0  326.0  242.0    271.0   172.0     69.0   13.0
# 1  1993   234.0   377.0  242.0  326.0  240.0    266.0   184.0     71.0   14.0
# 2  1994   237.0   378.0  242.0  326.0  238.0    250.0   196.0     72.0   16.0
# 3  1995   239.0   377.0  246.0  326.0  236.0    225.0   207.0     73.0   18.0
# 4  1996   242.0   375.0  242.0  327.0  234.0    200.0   213.0     73.0   20.0
#
#    WMO Minor  SUM* (ppt)  EESC SUM (ppt; new)  ODGI(old) Mid Latitude  \
# 0        6.0      1945.0               1795.0                    98.8
# 1        6.0      1961.0               1846.0                    99.7
# 2        6.0      1961.0               1888.0                   100.0
# 3        6.0      1953.0               1917.0                    98.4
# 4        7.0      1933.0               1932.0                    97.4
#
#    ODGI(new) Mid-Lat
# 0               82.0
# 1               88.6
# 2               94.0
# 3               97.6
# 4               99.6

# %%
odgi1.describe()
# Out:
#              Year      CFC-12      CFC-11       CH3Cl       CH3Br        CCl4  \
# count    33.00000   33.000000   33.000000   33.000000   33.000000   33.000000
# mean   2008.00000  897.242424  726.181818  497.606061  493.939394  364.515152
# std       9.66954   31.131807   49.276297    5.476880   65.982450   43.278980
# min    1992.00000  832.000000  641.000000  490.000000  415.000000  294.000000
# 25%    2000.00000  876.000000  684.000000  493.000000  430.000000  327.000000
# 50%    2008.00000  904.000000  724.000000  497.000000  481.000000  366.000000
# 75%    2016.00000  926.000000  773.000000  500.000000  572.000000  402.000000
# max    2024.00000  934.000000  796.000000  513.000000  596.000000  431.000000
#
#           CH3CCl3      halons     CFC-113       HCFCs  WMO Minor   SUM* (ppt)  \
# count   33.000000   33.000000   33.000000   33.000000  33.000000    33.000000
# mean   100.939394  455.969697  206.363636  110.272727  17.333333  3870.333333
# std    128.537674   41.400094   14.859379   37.466879   2.160247   263.835255
# min      3.000000  346.000000  181.000000   41.000000  14.000000  3438.000000
# 25%      8.000000  427.000000  194.000000   81.000000  15.000000  3661.000000
# 50%     35.000000  467.000000  208.000000  116.000000  18.000000  3869.000000
# 75%    149.000000  490.000000  219.000000  147.000000  19.000000  4133.000000
# max    400.000000  505.000000  227.000000  153.000000  21.000000  4248.000000
#
#        EESC SUM (ppt)  ODGI(old) Antarctic  ODGI(new) Antarctic
# count       33.000000            33.000000            33.000000
# mean      3894.090909            53.603030            87.133333
# std        191.117661            46.919922             9.559539
# min       3544.000000             0.000000            69.600000
# 25%       3735.000000             0.000000            79.200000
# 50%       3902.000000            85.800000            87.500000
# 75%       4069.000000            95.400000            95.900000
# max       4151.000000           100.000000           100.000000

# %%
odgi2.describe()
# Out:
#              Year      CFC-12      CFC-11       CH3Cl       CH3Br        CCl4  \
# count    33.00000   33.000000   33.000000   33.000000   33.000000   33.000000
# mean   2008.00000  240.000000  344.787879  240.606061  276.363636  204.060606
# std       9.66954    8.396428   23.366319    2.633194   36.882260   24.273107
# min    1992.00000  222.000000  304.000000  237.000000  232.000000  164.000000
# 25%    2000.00000  234.000000  325.000000  239.000000  241.000000  183.000000
# 50%    2008.00000  242.000000  344.000000  240.000000  269.000000  205.000000
# 75%    2016.00000  248.000000  367.000000  242.000000  320.000000  225.000000
# max    2024.00000  250.000000  378.000000  248.000000  333.000000  242.000000
#
#           CH3CCl3      halons    CFC-113      HCFCs  WMO Minor   SUM* (ppt)  \
# count   33.000000   33.000000  33.000000  33.000000  33.000000    33.000000
# mean    68.363636  224.181818  66.454545  38.000000   6.030303  1708.818182
# std     86.899661   22.122464   4.809437  13.152946   1.045372   159.485394
# min      2.000000  172.000000  58.000000  13.000000   4.000000  1474.000000
# 25%      6.000000  207.000000  62.000000  28.000000   5.000000  1580.000000
# 50%     24.000000  227.000000  67.000000  40.000000   6.000000  1691.000000
# 75%    101.000000  244.000000  71.000000  51.000000   7.000000  1852.000000
# max    271.000000  251.000000  73.000000  53.000000   8.000000  1961.000000
#
#        EESC SUM (ppt; new)  ODGI(old) Mid Latitude  ODGI(new) Mid-Lat
# count            33.000000               33.000000          33.000000
# mean           1736.484848               49.663636          74.372727
# std             140.384098               44.053056          18.130228
# min            1511.000000                0.000000          45.300000
# 25%            1610.000000                0.000000          58.000000
# 50%            1740.000000               72.600000          74.800000
# 75%            1866.000000               89.300000          91.100000
# max            1935.000000              100.000000         100.000000

# %%
# Checking for NaN values and filling them
odgi1 = odgi1.interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
odgi2 = odgi2.interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
# Out:
# C:\Users\Vaishnavi\AppData\Local\Temp\ipykernel_4836\439402631.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   odgi1 = odgi1.interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
# C:\Users\Vaishnavi\AppData\Local\Temp\ipykernel_4836\439402631.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   odgi2 = odgi2.interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')

# %%
odgi1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, 0 to 32
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 33 non-null     int64
#  1   CFC-12               33 non-null     float64
#  2   CFC-11               33 non-null     float64
#  3   CH3Cl                33 non-null     float64
#  4   CH3Br                33 non-null     float64
#  5   CCl4                 33 non-null     float64
#  6   CH3CCl3              33 non-null     float64
#  7   halons               33 non-null     float64
#  8   CFC-113              33 non-null     float64
#  9   HCFCs                33 non-null     float64
#  10  WMO Minor            33 non-null     float64
#  11  SUM* (ppt)           33 non-null     float64
#  12  EESC SUM (ppt)       33 non-null     float64
#  13  ODGI(old) Antarctic  33 non-null     float64
#  14  ODGI(new) Antarctic  33 non-null     float64
# dtypes: float64(14), int64(1)
# memory usage: 4.1 KB

# %%
odgi2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, 0 to 32
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Year                    33 non-null     int64
#  1   CFC-12                  33 non-null     float64
#  2   CFC-11                  33 non-null     float64
#  3   CH3Cl                   33 non-null     float64
#  4   CH3Br                   33 non-null     float64
#  5   CCl4                    33 non-null     float64
#  6   CH3CCl3                 33 non-null     float64
#  7   halons                  33 non-null     float64
#  8   CFC-113                 33 non-null     float64
#  9   HCFCs                   33 non-null     float64
#  10  WMO Minor               33 non-null     float64
#  11  SUM* (ppt)              33 non-null     float64
#  12  EESC SUM (ppt; new)     33 non-null     float64
#  13  ODGI(old) Mid Latitude  33 non-null     float64
#  14  ODGI(new) Mid-Lat       33 non-null     float64
# dtypes: float64(14), int64(1)
# memory usage: 4.1 KB

# %%
# Aligning year columns  for all datasets
antarctic_ozone['Year'] = antarctic_ozone['Year'].astype(int)
nasa2['Year'] = nasa2['Year'].astype(int)

# %%
antarctic_ozone['max_ozone_area_mil'] = antarctic_ozone['Maximum ozone hole area'] / 1e6
antarctic_ozone['mean_ozone_area_mil'] = antarctic_ozone['Mean ozone hole area'] / 1e6

merged = antarctic_ozone[['Year', 'max_ozone_area_mil', 'mean_ozone_area_mil']].merge(
    nasa2.rename(columns={'Ozone Hole area mean (mil km2)': 'nasa_mean_ozone_area', 'Minimum Ozone (DU)': 'nasa_min_ozone'}),
    on='Year', how='inner'
).merge(
    odgi1[['Year', 'EESC SUM (ppt)', 'ODGI(new) Antarctic']].rename(
        columns={'EESC SUM (ppt)': 'EESC_SUM_Antarctic', 'ODGI(new) Antarctic': 'ODGI_new_Antarctic'}
    ),
    on='Year', how='left'
).merge(
    odgi2[['Year', 'EESC SUM (ppt; new)', 'ODGI(new) Mid-Lat']].rename(
        columns={'EESC SUM (ppt; new)': 'EESC_SUM_MidLat', 'ODGI(new) Mid-Lat': 'ODGI_new_MidLat'}
    ),
    on='Year', how='left'
)

# %%
merged
# Out:
#     Year  max_ozone_area_mil  mean_ozone_area_mil  nasa_mean_ozone_area  \
# 0   1979                 1.1                  0.1                   0.1
# 1   1980                 3.3                  1.4                   1.4
# 2   1981                 3.1                  0.6                   0.6
# 3   1982                10.8                  4.8                   4.8
# 4   1983                12.2                  7.9                   7.9
# 5   1984                14.7                 10.1                  10.1
# 6   1985                18.8                 14.2                  14.2
# 7   1986                14.4                 11.3                  11.3
# 8   1987                22.5                 19.3                  19.3
# 9   1988                13.8                 10.0                  10.0
# 10  1989                21.7                 18.7                  18.7
# 11  1990                21.1                 19.2                  19.2
# 12  1991                22.6                 18.8                1808.0
# 13  1992                24.9                 22.3                  22.3
# 14  1993                25.8                 24.2                  24.2
# 15  1994                25.2                 23.6                  23.6
# 16  1996                26.9                 22.8                  22.8
# 17  1997                25.1                 22.1                  22.1
# 18  1998                27.9                 25.9                  25.9
# 19  1999                25.8                 23.3                  23.3
# 20  2000                29.9                 24.8                  24.8
# 21  2001                26.5                 25.0                  25.0
# 22  2002                21.9                 12.0                  12.0
# 23  2003                28.4                 25.8                  25.8
# 24  2004                22.8                 19.5                  19.5
# 25  2005                27.2                 24.4                  24.4
# 26  2006                29.6                 26.6                  26.6
# 27  2007                25.2                 22.0                  22.0
# 28  2008                27.0                 25.2                  25.2
# 29  2009                24.4                 22.0                  22.0
# 30  2010                22.6                 19.4                  19.4
# 31  2011                26.1                 24.7                  24.7
# 32  2012                21.1                 17.8                  17.8
# 33  2013                24.0                 21.0                  21.0
# 34  2014                24.1                 20.9                  20.9
# 35  2015                28.2                 25.6                  25.6
# 36  2016                22.8                 20.7                  20.7
# 37  2017                19.6                 17.4                  17.4
# 38  2018                24.8                 22.9                  22.9
# 39  2019                16.4                  9.3                   9.3
# 40  2020                24.8                 23.5                  23.5
# 41  2021                24.8                 23.3                  23.3
# 42  2022                26.5                 23.2                  23.2
# 43  2023                26.0                 23.1                  23.1
# 44  2024                22.4                 19.6                  19.6
#
#     nasa_min_ozone  EESC_SUM_Antarctic  ODGI_new_Antarctic  EESC_SUM_MidLat  \
# 0            225.0                 NaN                 NaN              NaN
# 1            203.0                 NaN                 NaN              NaN
# 2            209.5                 NaN                 NaN              NaN
# 3            185.0                 NaN                 NaN              NaN
# 4            172.9                 NaN                 NaN              NaN
# 5            163.6                 NaN                 NaN              NaN
# 6            146.5                 NaN                 NaN              NaN
# 7            157.8                 NaN                 NaN              NaN
# 8            123.0                 NaN                 NaN              NaN
# 9            171.0                 NaN                 NaN              NaN
# 10           127.0                 NaN                 NaN              NaN
# 11           124.2                 NaN                 NaN              NaN
# 12           119.0                 NaN                 NaN              NaN
# 13           114.3              3544.0                69.6           1795.0
# 14           112.6              3666.0                75.7           1846.0
# 15            92.3              3784.0                81.6           1888.0
# 16           108.8              3974.0                91.1           1932.0
# 17           108.8              4041.0                94.5           1935.0
# 18            98.8              4088.0                96.8           1928.0
# 19           102.9              4119.0                98.4           1918.0
# 20            98.7              4140.0                99.4           1907.0
# 21           100.9              4151.0               100.0           1890.0
# 22           157.4              4151.0               100.0           1866.0
# 23           108.7              4137.0                99.3           1840.0
# 24           123.5              4117.0                98.3           1816.0
# 25           113.8              4094.0                97.1           1795.0
# 26            98.4              4069.0                95.9           1776.0
# 27           116.2              4043.0                94.6           1757.0
# 28           114.0              4017.0                93.3           1740.0
# 29           107.9              3990.0                91.9           1723.0
# 30           128.5              3963.0                90.6           1705.0
# 31           106.5              3933.0                89.1           1686.0
# 32           139.3              3902.0                87.5           1669.0
# 33           132.7              3872.0                86.0           1654.0
# 34           128.6              3843.0                84.6           1640.0
# 35           117.2              3815.0                83.2           1624.0
# 36           123.2              3786.0                81.7           1610.0
# 37           141.8              3759.0                80.4           1599.0
# 38           111.8              3735.0                79.2           1587.0
# 39           167.0              3711.0                78.0           1575.0
# 40           102.6              3686.0                76.7           1562.0
# 41           103.3              3660.0                75.4           1550.0
# 42           112.5              3635.0                74.2           1538.0
# 43           115.2              3609.0                72.9           1525.0
# 44           121.0              3583.0                71.6           1511.0
#
#     ODGI_new_MidLat
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
# 6               NaN
# 7               NaN
# 8               NaN
# 9               NaN
# 10              NaN
# 11              NaN
# 12              NaN
# 13             82.0
# 14             88.6
# 15             94.0
# 16             99.6
# 17            100.0
# 18             99.1
# 19             97.8
# 20             96.4
# 21             94.2
# 22             91.1
# 23             87.7
# 24             84.7
# 25             82.0
# 26             79.4
# 27             77.0
# 28             74.8
# 29             72.6
# 30             70.3
# 31             67.9
# 32             65.7
# 33             63.7
# 34             61.9
# 35             59.8
# 36             58.0
# 37             56.6
# 38             55.1
# 39             53.5
# 40             51.8
# 41             50.3
# 42             48.7
# 43             47.1
# 44             45.3

# %%
# Save the final merged dataframe to a new CSV file
merged.to_csv('ozone_data_for_tableau.csv', index=False)

# %% [markdown]
# # Visualzing Trends

# %%
import seaborn as sns

# Set a modern plot style
sns.set_theme(style="whitegrid")

# --- Create the plot ---
fig, ax1 = plt.subplots(figsize=(14, 8))

# --- Plot 1: Ozone Hole Area (The Effect) on the left Y-axis ---
# Using a rolling average to smooth out the year-to-year noise and show the trend
ax1.plot(merged['Year'], merged['mean_ozone_area_mil'].rolling(window=3, center=True).mean(), 
         color='tab:red', marker='o', linestyle='-', label='Mean Ozone Hole Area (smoothed)')

ax1.set_xlabel('Year', fontsize=12)
ax1.set_ylabel('Mean Ozone Hole Area (million km²)', color='tab:red', fontsize=12)
ax1.tick_params(axis='y', labelcolor='tab:red')

# --- Plot 2: EESC (The Cause) on the right Y-axis ---
# Create a second Y-axis that shares the same X-axis
ax2 = ax1.twinx()
ax2.plot(merged['Year'], merged['EESC_SUM_Antarctic'], 
         color='tab:blue', marker='x', linestyle='--', label='Ozone Depleting Chemicals (EESC)')
ax2.set_ylabel('EESC SUM (ppt)', color='tab:blue', fontsize=12)
ax2.tick_params(axis='y', labelcolor='tab:blue')

# --- Add context and labels ---
# Add a vertical line to mark the Montreal Protocol
plt.axvline(x=1987, color='grey', linestyle=':', linewidth=2, label='Montreal Protocol (1987)')

plt.title('Impact of Ozone-Depleting Chemicals on the Antarctic Ozone Hole', fontsize=16)
fig.legend(loc="upper center", bbox_to_anchor=(0.5, 0.95), ncol=3)
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout(rect=[0, 0, 1, 0.9]) # Adjust layout to make space for the legend
plt.show()

# %%
# Set a modern plot style
sns.set_theme(style="whitegrid")

# Create a figure with 3 subplots that share the same x-axis
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(12, 15), sharex=True)

# --- Plot 1: Mean Ozone Hole Area ---
ax1.plot(merged['Year'], merged['mean_ozone_area_mil'], color='tab:blue', label='Mean Ozone Hole Area')
ax1.set_ylabel('Area (million km²)')
ax1.set_title('Antarctic Ozone Hole: Area, Minimum Concentration, and ODGI')
ax1.legend()
ax1.grid(True)

# --- Plot 2: Minimum Ozone Concentration ---
# This shows how thin the ozone layer gets. A lower number is worse.
ax2.plot(merged['Year'], merged['nasa_min_ozone'], color='tab:green', label='Minimum Ozone')
ax2.set_ylabel('Dobson Units (DU)')
ax2.legend()
ax2.grid(True)

# --- Plot 3: Ozone Depleting Gas Index ---
ax3.plot(merged['Year'], merged['ODGI_new_Antarctic'], color='tab:red', label='ODGI (Antarctic)')
ax3.set_xlabel('Year')
ax3.set_ylabel('Ozone Depleting Gas Index')
ax3.legend()
ax3.grid(True)

# Display the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# # Model building

# %%
features = 'EESC_SUM_Antarctic'
target = 'mean_ozone_area_mil'

model_data = merged[[features, target]].dropna()

# %%
from sklearn.preprocessing import MinMaxScaler

# --- Step 1.2: Scale the Data ---

# Initialize the scaler
scaler = MinMaxScaler(feature_range=(0, 1))

# Fit and transform the data
scaled_data = scaler.fit_transform(model_data)

scaled_data
# Out:
# array([[0.        , 0.75144509],
#        [0.20098847, 0.86127168],
#        [0.39538715, 0.8265896 ],
#        [0.70840198, 0.78034682],
#        [0.81878089, 0.73988439],
#        [0.89621087, 0.95953757],
#        [0.94728171, 0.80924855],
#        [0.98187809, 0.89595376],
#        [1.        , 0.90751445],
#        [1.        , 0.15606936],
#        [0.97693575, 0.95375723],
#        [0.94398682, 0.58959538],
#        [0.90609555, 0.87283237],
#        [0.86490939, 1.        ],
#        [0.82207578, 0.73410405],
#        [0.77924217, 0.91907514],
#        [0.73476112, 0.73410405],
#        [0.69028007, 0.58381503],
#        [0.64085667, 0.89017341],
#        [0.58978583, 0.49132948],
#        [0.54036244, 0.67630058],
#        [0.49258649, 0.67052023],
#        [0.44645799, 0.94219653],
#        [0.39868204, 0.65895954],
#        [0.35420099, 0.46820809],
#        [0.31466227, 0.78612717],
#        [0.27512356, 0.        ],
#        [0.2339374 , 0.82080925],
#        [0.19110379, 0.80924855],
#        [0.14991763, 0.80346821],
#        [0.10708402, 0.79768786],
#        [0.06425041, 0.59537572]])

# %%
import numpy as np

# --- Step 1.3: Create Time Series Sequences ---

def create_sequences(data, look_back=3):
    """
    Creates sequences of data for LSTM.
    'look_back' is the number of previous time steps to use as input variables (X)
    to predict the next time period (y).
    """
    X, y = [], []
    for i in range(len(data) - look_back):
        # The features are the sequence of 'look_back' days
        X.append(data[i:(i + look_back), :-1]) # All columns except the last one (target)
        # The target is the 'Mean ozone hole area' on the next day
        y.append(data[i + look_back, -1]) # The last column
    return np.array(X), np.array(y)

# Let's use a look_back period of 3 years
look_back = 3
X, y = create_sequences(scaled_data, look_back)

print("Shape of X (input sequences):", X.shape)
print("Shape of y (target):", y.shape)
# Out:
# Shape of X (input sequences): (29, 3, 1)
# Shape of y (target): (29,)

# %%
# --- Step 1.4: Train-Test Split ---

# Let's use 80% of the data for training and 20% for testing
train_size = int(len(X) * 0.8)
test_size = len(X) - train_size

X_train, X_test = X[0:train_size], X[train_size:len(X)]
y_train, y_test = y[0:train_size], y[train_size:len(y)]

print("Training set size:", len(X_train))
print("Test set size:", len(X_test))
# Out:
# Training set size: 23
# Test set size: 6

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# --- Step 2: Building the LSTM Model ---

# The input shape is (look_back, number_of_features)
input_shape = (X_train.shape[1], X_train.shape[2])

model = Sequential()

# Add an LSTM layer with 50 units
# 'return_sequences=True' is needed if you stack LSTM layers
model.add(LSTM(units=50, return_sequences=True, input_shape=input_shape))
model.add(Dropout(0.2)) # Dropout for regularization

# Add a second LSTM layer
model.add(LSTM(units=50))
model.add(Dropout(0.2))

# Add a Dense output layer with 1 neuron (to predict our single target value)
model.add(Dense(units=1))

# Display the model's architecture
model.summary()
# Out:
# c:\Users\Vaishnavi\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 3, 50)          │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 3, 50)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 30,651 (119.73 KB)
#  Trainable params: 30,651 (119.73 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# --- Step 3: Compiling and Training the Model ---

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
# We use the test data for validation to monitor performance on unseen data during training
history = model.fit(
    X_train,
    y_train,
    epochs=150, # Number of times to iterate over the entire dataset
    batch_size=8, # Number of samples per gradient update
    validation_data=(X_test, y_test),
    verbose=1 # Show training progress
)
# Out:
# Epoch 1/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 339ms/step - loss: 0.0379 - val_loss: 0.1042
# Epoch 2/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0365 - val_loss: 0.0989
# Epoch 3/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0433 - val_loss: 0.0931
# Epoch 4/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0505 - val_loss: 0.0904
# Epoch 5/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0403 - val_loss: 0.0908
# Epoch 6/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0422 - val_loss: 0.0935
# Epoch 7/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0414 - val_loss: 0.0960
# Epoch 8/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0321 - val_loss: 0.0982
# Epoch 9/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0363 - val_loss: 0.0975
# Epoch 10/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0434 - val_loss: 0.0955
# Epoch 11/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0390 - val_loss: 0.0940
# Epoch 12/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0392 - val_loss: 0.0936
# Epoch 13/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0438 - val_loss: 0.0937
# Epoch 14/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0401 - val_loss: 0.0960
# Epoch 15/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0371 - val_loss: 0.1002
# Epoch 16/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0430 - val_loss: 0.0989
# Epoch 17/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0370 - val_loss: 0.0949
# Epoch 18/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0411 - val_loss: 0.0931
# Epoch 19/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0472 - val_loss: 0.0933
# Epoch 20/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0500 - val_loss: 0.0933
# Epoch 21/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0445 - val_loss: 0.0951
# Epoch 22/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0370 - val_loss: 0.0952
# Epoch 23/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0405 - val_loss: 0.0959
# Epoch 24/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0516 - val_loss: 0.0976
# Epoch 25/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0436 - val_loss: 0.0962
# Epoch 26/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0399 - val_loss: 0.0948
# Epoch 27/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0391 - val_loss: 0.0940
# Epoch 28/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0415 - val_loss: 0.0939
# Epoch 29/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0335 - val_loss: 0.0958
# Epoch 30/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0463 - val_loss: 0.0956
# Epoch 31/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0272 - val_loss: 0.0957
# Epoch 32/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0330 - val_loss: 0.0975
# Epoch 33/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0407 - val_loss: 0.0980
# Epoch 34/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0486 - val_loss: 0.0961
# Epoch 35/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0404 - val_loss: 0.0969
# Epoch 36/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0395 - val_loss: 0.0959
# Epoch 37/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0362 - val_loss: 0.0966
# Epoch 38/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0407 - val_loss: 0.0971
# Epoch 39/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0389 - val_loss: 0.0992
# Epoch 40/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0390 - val_loss: 0.0986
# Epoch 41/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0494 - val_loss: 0.0975
# Epoch 42/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0315 - val_loss: 0.0961
# Epoch 43/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0457 - val_loss: 0.0940
# Epoch 44/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0434 - val_loss: 0.0928
# Epoch 45/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0362 - val_loss: 0.0940
# Epoch 46/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0389 - val_loss: 0.0949
# Epoch 47/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0345 - val_loss: 0.0971
# Epoch 48/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0463 - val_loss: 0.1013
# Epoch 49/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0448 - val_loss: 0.0980
# Epoch 50/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0346 - val_loss: 0.0954
# Epoch 51/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0464 - val_loss: 0.0938
# Epoch 52/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0428 - val_loss: 0.0939
# Epoch 53/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0434 - val_loss: 0.0932
# Epoch 54/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0335 - val_loss: 0.0944
# Epoch 55/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0399 - val_loss: 0.0966
# Epoch 56/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0386 - val_loss: 0.1005
# Epoch 57/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0432 - val_loss: 0.0996
# Epoch 58/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0402 - val_loss: 0.0967
# Epoch 59/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0451 - val_loss: 0.0954
# Epoch 60/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0464 - val_loss: 0.0961
# Epoch 61/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0353 - val_loss: 0.0975
# Epoch 62/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0419 - val_loss: 0.0961
# Epoch 63/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0446 - val_loss: 0.0946
# Epoch 64/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0354 - val_loss: 0.0945
# Epoch 65/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0361 - val_loss: 0.0942
# Epoch 66/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0410 - val_loss: 0.0947
# Epoch 67/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0388 - val_loss: 0.0964
# Epoch 68/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0363 - val_loss: 0.0969
# Epoch 69/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0370 - val_loss: 0.0969
# Epoch 70/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0406 - val_loss: 0.0958
# Epoch 71/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0396 - val_loss: 0.0949
# Epoch 72/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0403 - val_loss: 0.0963
# Epoch 73/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0424 - val_loss: 0.0976
# Epoch 74/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0454 - val_loss: 0.0980
# Epoch 75/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0445 - val_loss: 0.0971
# Epoch 76/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0350 - val_loss: 0.0968
# Epoch 77/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0347 - val_loss: 0.0960
# Epoch 78/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0421 - val_loss: 0.0958
# Epoch 79/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0355 - val_loss: 0.0969
# Epoch 80/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0487 - val_loss: 0.0996
# Epoch 81/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0420 - val_loss: 0.0974
# Epoch 82/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0362 - val_loss: 0.0967
# Epoch 83/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0404 - val_loss: 0.0959
# Epoch 84/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0398 - val_loss: 0.0943
# Epoch 85/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0383 - val_loss: 0.0947
# Epoch 86/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 0.0423 - val_loss: 0.0944
# Epoch 87/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0416 - val_loss: 0.0951
# Epoch 88/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0368 - val_loss: 0.0941
# Epoch 89/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0451 - val_loss: 0.0946
# Epoch 90/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0442 - val_loss: 0.0944
# Epoch 91/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0445 - val_loss: 0.0940
# Epoch 92/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0410 - val_loss: 0.0956
# Epoch 93/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0351 - val_loss: 0.1004
# Epoch 94/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0439 - val_loss: 0.1017
# Epoch 95/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0428 - val_loss: 0.1007
# Epoch 96/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0419 - val_loss: 0.0956
# Epoch 97/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0456 - val_loss: 0.0928
# Epoch 98/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0429 - val_loss: 0.0918
# Epoch 99/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0415 - val_loss: 0.0924
# Epoch 100/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0427 - val_loss: 0.0958
# Epoch 101/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0360 - val_loss: 0.0982
# Epoch 102/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0452 - val_loss: 0.1006
# Epoch 103/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0389 - val_loss: 0.0985
# Epoch 104/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0426 - val_loss: 0.0983
# Epoch 105/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0399 - val_loss: 0.0977
# Epoch 106/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0375 - val_loss: 0.0969
# Epoch 107/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0442 - val_loss: 0.0966
# Epoch 108/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0405 - val_loss: 0.0947
# Epoch 109/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0420 - val_loss: 0.0935
# Epoch 110/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0459 - val_loss: 0.0938
# Epoch 111/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0390 - val_loss: 0.0968
# Epoch 112/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0380 - val_loss: 0.0980
# Epoch 113/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0358 - val_loss: 0.0967
# Epoch 114/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0391 - val_loss: 0.0962
# Epoch 115/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0353 - val_loss: 0.0970
# Epoch 116/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0400 - val_loss: 0.0959
# Epoch 117/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0405 - val_loss: 0.0962
# Epoch 118/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0409 - val_loss: 0.0945
# Epoch 119/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0376 - val_loss: 0.0937
# Epoch 120/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0384 - val_loss: 0.0943
# Epoch 121/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0401 - val_loss: 0.0956
# Epoch 122/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0397 - val_loss: 0.0979
# Epoch 123/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0378 - val_loss: 0.0986
# Epoch 124/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0339 - val_loss: 0.0995
# Epoch 125/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0433 - val_loss: 0.0977
# Epoch 126/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0424 - val_loss: 0.0963
# Epoch 127/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0359 - val_loss: 0.0960
# Epoch 128/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0431 - val_loss: 0.0946
# Epoch 129/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0438 - val_loss: 0.0948
# Epoch 130/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0393 - val_loss: 0.0950
# Epoch 131/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0444 - val_loss: 0.0952
# Epoch 132/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0373 - val_loss: 0.0942
# Epoch 133/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0370 - val_loss: 0.0960
# Epoch 134/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0408 - val_loss: 0.0963
# Epoch 135/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0451 - val_loss: 0.0932
# Epoch 136/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0387 - val_loss: 0.0930
# Epoch 137/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0376 - val_loss: 0.0946
# Epoch 138/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0357 - val_loss: 0.0970
# Epoch 139/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0357 - val_loss: 0.0979
# Epoch 140/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0527 - val_loss: 0.0946
# Epoch 141/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0332 - val_loss: 0.0943
# Epoch 142/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0411 - val_loss: 0.0938
# Epoch 143/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0324 - val_loss: 0.0960
# Epoch 144/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0431 - val_loss: 0.0956
# Epoch 145/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0436 - val_loss: 0.0975
# Epoch 146/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0380 - val_loss: 0.0969
# Epoch 147/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0436 - val_loss: 0.0951
# Epoch 148/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0452 - val_loss: 0.0934
# Epoch 149/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0465 - val_loss: 0.0918
# Epoch 150/150
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0473 - val_loss: 0.0922

# %%
# --- Step 4.1: Making Predictions and Inverse Scaling ---

# Make predictions on the test set
predicted_scaled = model.predict(X_test)

# To inverse transform, we need to create an array of the same shape as the scaler expects
# (number_of_samples, number_of_features + 1)
num_features = model_data.shape[1] - 1
# Create a dummy array with zeros
dummy_array_pred = np.zeros((len(predicted_scaled), num_features + 1))
# Place our scaled predictions into the last column (the target column)
dummy_array_pred[:, -1] = predicted_scaled.ravel()
# Inverse transform
predictions = scaler.inverse_transform(dummy_array_pred)[:, -1]


# Do the same for the actual test values (y_test)
dummy_array_actual = np.zeros((len(y_test), num_features + 1))
dummy_array_actual[:, -1] = y_test.ravel()
y_test_actual = scaler.inverse_transform(dummy_array_actual)[:, -1]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step

# %%
import matplotlib.pyplot as plt

# --- Step 4.2: Visualizing the Results ---

# Plot training & validation loss values
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss (MSE)')
plt.xlabel('Epoch')
plt.legend()
plt.grid(True)
plt.show()

# Plot the actual vs predicted values
plt.figure(figsize=(14, 7))
plt.plot(y_test_actual, color='blue', label='Actual Ozone Hole Area')
plt.plot(predictions, color='red', linestyle='--', label='Predicted Ozone Hole Area')
plt.title('Ozone Hole Area Prediction')
plt.xlabel('Time (Test Set)')
plt.ylabel('Mean Ozone Hole Area (km^2)')
plt.legend()
plt.grid(True)
plt.show()

# Calculate some error metric
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test_actual, predictions))
print(f"Root Mean Squared Error (RMSE): {rmse:,.0f} km^2")
# Out:
# Root Mean Squared Error (RMSE): 5 km^2
